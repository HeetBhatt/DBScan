# %%
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([[1,2],[2,2],[2,3],[8,9],[39,9],[10,10]])

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
db = DBSCAN(eps=3,min_samples=2)
db.fit(X)
db.labels_
# Out:
# array([ 0,  0,  0,  1, -1,  1])
